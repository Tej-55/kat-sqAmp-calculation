# %%
# !pip install tensordict einx axial_positional_embedding rotary_embedding_torch x_transformers hyper_connections accelerated_scan Ninja
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 3.3 MB/s eta 0:00:00
# ...

# %%
# !pip install torchtext==0.17.2 torch torchvision

# %%
# !git clone https://github.com/Tej-55/GSoC-TITANS.git

# %%
# %cd GSoC-TITANS

# %%
# !python -m torch.distributed.launch --nproc_per_node=2 titans_main.py \
  --batch_size=8 \
  --num_epochs=5 \
  --lr=5e-5 \
  --segment_len=512 \
  --dim=128 \
  --depth=6 \
  --heads=8 \
  --depth_mem=2
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/distributed/launch.py:183: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use-env is set by default in torchrun.
# If your script expects `--local-rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   warnings.warn(
# [2025-03-19 20:04:38,379] torch.distributed.run: [WARNING]
# [2025-03-19 20:04:38,379] torch.distributed.run: [WARNING] *****************************************
# [2025-03-19 20:04:38,379] torch.distributed.run: [WARNING] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# ...

# %%
# !zip -r model_titans.zip model_titans
# Out:
#   adding: model_titans/ (stored 0%)
#   adding: model_titans/titans_model.pt (deflated 9%)
#   adding: model_titans/training_history.png (deflated 12%)
